# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
error = pd.read_csv('friction_error.csv')
pid = pd.read_csv('friction_pid.csv')

# %%
error.head()
# Out:
#    ElapsedTime  FrictionForceMagnitude
# 0            1                981000.1
# 1            2                986000.1
# 2            3                991000.1
# 3            4                996000.1
# 4            5               1001000.0

# %%
error = np.array(error['FrictionForceMagnitude'])
pid = np.array(pid['Friction'])

# %%
error.shape, pid.shape
# Out:
# ((1100,), (1100,))

# %%
# error = error[0:500]
# pid = pid[0:500]

# %%
error = error/np.min(error)
pid = pid/np.min(pid)

# %%
plt.figure(figsize=(10, 6))
plt.plot(error, label='Error')
plt.plot(pid, label='PID error')
plt.xlabel('Index')
plt.ylabel('Friction Force Magnitude')
plt.legend()
plt.show()
