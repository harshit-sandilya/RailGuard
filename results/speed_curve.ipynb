# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('speeds_full.csv')
X = df['Speed'].values
X = np.array(X)
X.shape
X = X[:450]

# %%
plt.plot(X)
plt.title('Speed Curve')
plt.xlabel('Elapsed Time')
plt.ylabel('Speed')
plt.show()
